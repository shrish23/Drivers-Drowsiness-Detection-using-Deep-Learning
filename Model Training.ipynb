# %%
# !pip install tensorflow
# Out:
# ...
#   Created wheel for clang: filename=clang-5.0-py3-none-any.whl size=30703 sha256=e1e4b886b67cac9118d430ac566967d2ae384c286cda018f3bc5c6faab1deea8
#   Stored in directory: c:\users\shrish\appdata\local\pip\cache\wheels\f1\60\77\22b9b5887bd47801796a856f47650d9789c74dc3161a26d608
# ...
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4829 sha256=4de2bc352673a0681c5bf5728a53807849e484db8fb4756aa04d940b75a29707
#   Stored in directory: c:\users\shrish\appdata\local\pip\cache\wheels\a0\16\9c\5473df82468f958445479c59e784896fa24f4a5fc024b0f501
# ...
#   Created wheel for wrapt: filename=wrapt-1.12.1-py3-none-any.whl size=19553 sha256=aed43d3a10f6e380d66b331bdad6285814a1a8ff5f513cc536d81ff571c40ea6
#   Stored in directory: c:\users\shrish\appdata\local\pip\cache\wheels\5f\fd\9e\b6cf5890494cb8ef0b5eaff72e5d55a70fb56316007d6dfe73
# Successfully built clang termcolor wrapt
# ...
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
# ...

# %%
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dropout,Input,Flatten,Dense,MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
train_datagen = ImageDataGenerator(rescale=1./255,rotation_range=0.2,shear_range=0.2,zoom_range=0.2,width_shift_range=0.2,height_shift_range=0.2,validation_split=0.2)

# %%
train_data = train_datagen.flow_from_directory(r'D:\ML Projects\Drivers Drowsiness Detection using Deep Learning\MRL Eye Data\Prepared_Data\Train',target_size=(80,80),batch_size=8,class_mode='categorical',subset='training')

validation_data = train_datagen.flow_from_directory(r'D:\ML Projects\Drivers Drowsiness Detection using Deep Learning\MRL Eye Data\Prepared_Data\Train',target_size=(80,80),batch_size=8,class_mode='categorical',subset='validation')
# Out:
# Found 64693 images belonging to 2 classes.
# Found 16173 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_data = test_datagen.flow_from_directory(r'D:\ML Projects\Drivers Drowsiness Detection using Deep Learning\MRL Eye Data\Prepared_Data\Test',target_size=(80,80),batch_size=8,class_mode='categorical')
# Out:
# Found 4032 images belonging to 2 classes.

# %%
bmodel = InceptionV3(include_top=True,weights='imagenet',input_tensor=Input(shape=(80,80,3),batch_size=8))
hmodel = bmodel.output
hmodel = Flatten()(hmodel)
hmodel = Dense(64, activation='relu')(hmodel)
hmodel = Dropout(0.5)(hmodel)
hmodel = Dense(2,activation='softmax')(hmodel)

model = Model(inputs=bmodel.input,outputs=hmodel)
for layer in bmodel.layers:
    layer.trainable = False

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(8, 80, 80, 3)]     0
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (8, 39, 39, 32)      864         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (8, 39, 39, 32)      96          conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (8, 39, 39, 32)      0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# ...
